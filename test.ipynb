# %%
from helpers import prep_greg_data

# %%
df = prep_greg_data("2025-06", "2025-06")
# Out:
# Loading cached data from data/prep_greg_data_2025-06_to_2025-06.parquet

# %%
df.head()
# Out:
#     DAY_DATE  COMPANY_ID                                  COMPANY_NAME  \
# 0 2025-06-30    10081196  Fidelity National Information Services, Inc.
# 1 2025-06-30     1455350                   Fennec Pharmaceuticals Inc.
# 2 2025-06-30      288502                             Merck & Co., Inc.
# 3 2025-06-30   132698650         Bridge Investment Group Holdings Inc.
# 4 2025-06-30      374377                         Cheniere Energy, Inc.
#
#                         INDUSTRY  \
# 0             Financial Services
# 1                  Biotechnology
# 2                Pharmaceuticals
# 3                Capital Markets
# 4  Oil, Gas and Consumable Fuels
#
#                                      INDUSTRY_GROUP INDUSTRY_SECTOR  \
# 0                                Financial Services      Financials
# 1  Pharmaceuticals, Biotechnology and Life Sciences     Health Care
# 2  Pharmaceuticals, Biotechnology and Life Sciences     Health Care
# ...

# %%
# TODO: remove "All Date" option from date selector
# NOTE: current df doesn't have TICKER, that's why it doesn't work in dashboard
